# %%
import pandas as pd

df = pd.read_csv(r"D:\cllg projects\AI-Career-Intelligence-Platform\backend\datasets\student_placement_prediction_dataset_2026.csv")

print(df.groupby("placement_status")["cgpa"].mean())
print(df.groupby("placement_status")["coding_skill_score"].mean())
print(df.groupby("placement_status")["aptitude_score"].mean())
print(df.groupby("placement_status")["communication_skill_score"].mean())
print(df.groupby("placement_status")["internships_count"].mean())
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# placement_status
# Not Placed    7.483789
# Placed        7.507846
# Name: cgpa, dtype: float64
# placement_status
# Not Placed    69.009449
# Placed        70.507598
# Name: coding_skill_score, dtype: float64
# placement_status
# Not Placed    64.473703
# Placed        65.418276
# Name: aptitude_score, dtype: float64
# placement_status
# Not Placed    67.472542
# Placed        68.368999
# Name: communication_skill_score, dtype: float64
# placement_status
# Not Placed    1.417163
# Placed        1.573367
# Name: internships_count, dtype: float64

# %%
print(df.select_dtypes(include="object").columns.tolist())

for col in df.select_dtypes(include="object").columns:
    print("\n", col)
    print(df[col].value_counts().head())
# Out:
# ['gender', 'branch', 'college_tier', 'volunteer_experience', 'placement_status']
#
#  gender
# gender
# Male      60028
# Female    39972
# Name: count, dtype: int64
#
#  branch
# branch
# CSE           34818
# IT            19999
# ECE           14908
# EEE           10177
# Mechanical    10077
# Name: count, dtype: int64
#
#  college_tier
# college_tier
# Tier 2    49955
# Tier 3    29884
# Tier 1    20161
# Name: count, dtype: int64
#
#  volunteer_experience
# volunteer_experience
# No     59963
# Yes    40037
# Name: count, dtype: int64
#
#  placement_status
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64
# ...

# %%
import pandas as pd

df = pd.read_csv(r"D:\cllg projects\AI-Career-Intelligence-Platform\backend\datasets\student_placement_dataset_1M.csv")

corr = df.corr(numeric_only=True)["placed"].sort_values(ascending=False)

print(corr)
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# placed                   1.000000
# java_skill               0.140398
# python_skill             0.139277
# c++_skill                0.138423
# web_dev_skill            0.138010
# ml_skill                 0.137330
# cgpa                     0.115080
# internships              0.093855
# aptitude_score           0.086057
# logical_reasoning        0.085608
# problem_solving          0.082241
# teamwork                 0.081959
# leadership               0.081849
# github_projects          0.078262
# hackathons               0.075409
# projects                 0.065816
# city_tier                0.002301
# time_management          0.001689
# coding_contest_rating    0.001370
# certifications           0.001164
# ...

# %%
print(df.columns.tolist())
# Out:
# ['age', 'cgpa', 'backlogs', 'attendance', 'tenth_percentage', 'twelfth_percentage', 'branch', 'college_tier', 'python_skill', 'c++_skill', 'java_skill', 'ml_skill', 'web_dev_skill', 'communication_skill', 'aptitude_score', 'logical_reasoning', 'internships', 'projects', 'github_projects', 'hackathons', 'certifications', 'coding_contest_rating', 'teamwork', 'leadership', 'problem_solving', 'time_management', 'gender', 'city_tier', 'family_income', 'placed']
