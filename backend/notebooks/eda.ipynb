# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"D:\cllg projects\AI-Career-Intelligence-Platform\backend\datasets\student_placement_prediction_dataset_2026.csv")

print(df.info())
print("\n")

print(df.isnull().sum())
print("\n")

print(df["placement_status"].value_counts())
print("\n")

print(df.describe())
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 5 df = pd.read_csv(r"D:\cllg projects\AI-Career-Intelligence-Platform\backend\datasets\student_placement_prediction_dataset_2026.csv")
#       7 print(df.info())
#       8 print("\n")
#
# ...

# %%
print(df.columns.tolist())

print("\nPlacement Status Values:")
print(df["placement_status"].value_counts())

print("\nSalary Statistics:")
print(df["salary_package_lpa"].describe())
# Out:
# ['student_id', 'age', 'gender', 'cgpa', 'branch', 'college_tier', 'internships_count', 'projects_count', 'certifications_count', 'coding_skill_score', 'aptitude_score', 'communication_skill_score', 'logical_reasoning_score', 'hackathons_participated', 'github_repos', 'linkedin_connections', 'mock_interview_score', 'attendance_percentage', 'backlogs', 'extracurricular_score', 'leadership_score', 'volunteer_experience', 'sleep_hours', 'study_hours_per_day', 'placement_status', 'salary_package_lpa']
#
# Placement Status Values:
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64
#
# Salary Statistics:
# count    100000.000000
# mean          7.252106
# std           6.735132
# min           0.000000
# 25%           0.000000
# 50%          11.100000
# 75%          13.470000
# max          20.440000
# Name: salary_package_lpa, dtype: float64

# %%
# Placement distribution
df["placement_status"].value_counts().plot(kind="bar")

plt.title("Placement Distribution")
plt.show()

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.select_dtypes(include=['int64','float64']).corr(),
    cmap='coolwarm'
)

plt.show()

# %%
print(df.drop("placed", axis=1).columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df.drop("placed", axis=1).columns.tolist())
#
# NameError: name 'df' is not defined
